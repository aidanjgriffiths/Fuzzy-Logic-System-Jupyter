# %%
from fuzzyLogic import auto_braking
# %matplotlib inline

# auto_braking(distance_input, speed_input)

# %% [markdown]
# <h1>Test 1</h1>
# <ul>
#     <p>Input: Distance is 0.5 m (Very close) and Speed is 99 km/h (Very Fast)</p>
#     <p>Output: Braking force is 86.46% (Very Heavy)</p>
# </ul>

# %%
auto_braking(0.5,99)
# Out:
# 86.46015225980534

# %% [markdown]
# <h1>Test 2</h1>
# <ul>
#     <p>Input: Distance is 9.8 m (Very Far) and Speed is 30 km/h (Very Slow)</p>
#     <p>Output: Braking force is 15.30% (Very Light)</p>
# </ul>

# %%
auto_braking(9.8,30)
# Out:
# 15.302702702702726

# %% [markdown]
# <h1>Test 3</h1>
# <ul>
#     <p>Input: Distance is 3.8 m (Close) and Speed is 37 km/h (Slow)</p>
#     <p>Output: Braking force is 38.25% (Light)</p>
# </ul>

# %%
auto_braking(3.8, 37)
# Out:
# 38.24561403508773

# %% [markdown]
# <h1>Test 4</h1>
# <ul>
#     <p>Input: Distance is 6.5 m (Far) and Speed is 69 km/h (Fast)</p>
#     <p>Output: Braking force is 64.36% (Heavy)</p>
# </ul>

# %%
auto_braking(6.5, 69)
# Out:
# 64.36615683418304
